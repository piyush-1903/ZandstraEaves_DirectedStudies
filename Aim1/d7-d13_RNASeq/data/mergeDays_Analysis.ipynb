# %%
#Loading Libraries 

library(BiocSingular)
library(SingleCellExperiment)
library(scuttle)
library(scran)
library(scater)
library(GO.db)
library(limma)
library(org.Hs.eg.db)
#library(scDblFinder)
#library(DropletUtils)
#library(DropletTestFiles)
library(uwot)
#library(rtracklayer)
#library(PCAtools)
#library(celldex)
#library(SingleR)
#library(batchelor)
library(bluster)

# %%
load("data/phenotype_with_ID.RData")
load("merge2.RData")

# %% [markdown]
# We have now loaded pre-processed merge2 data, and the associated phenotypes. Lets create an index linking cells to  phenotype as well.

# %%
pheno.d7 <- rep("CD34+CD45RA-CLEC12A-", 3039)
names(pheno.d7) <- colnames(merge2)[1:3039]

pheno.merge2 <- c(pheno.d7, pheno.d10, pheno.d13)

# %% [markdown]
# Great, now lets begin by doing PCA on our SCE object called merge2. First, we will take the top 30% of the genes, and then we will do PCA on that.

# %%
#PCA has already been done on the top genes 
reducedDimNames(merge2)
# Out:
# [1] "PCA.cc"    "UMAP.cc"   "PCA.5k"    "PCA.nocc"  "UMAP.nocc" "TSNE.nocc"
# [7] "TSNE.5k"   "PCA"       "TSNE"

# %% [markdown]
# Ok nice - next we add phenotype metadata

# %%
# Add phenotypes as a column in colData
colData(merge2)$Phenotype <- pheno.merge2

# %%
gg_umap <- ggplot(umap_df, aes(x = UMAP1, y = UMAP2, color = Phenotype)) +
  geom_point(alpha = 0.8, size = 1) +
  labs(
    title = "UMAP of Day 7 - Day13 Gene Expression",
    x = "UMAP1",
    y = "UMAP2",
    color = "Phenotype"
  ) +
  theme_minimal(base_size = 14) +
  theme(
    plot.title = element_text(hjust = 0.5, face = "bold"),
    legend.position = "bottom",
    legend.title = element_text(face = "bold"),
    legend.box = "horizontal",
    legend.text = element_text(size = 10)  # Adjust legend text size
  ) +
  guides(color = guide_legend(nrow = 5))  # Split legend into 2 rows

print(gg_umap)
# Out:
# plot without title

# %% [markdown]
# Too many groups, lets simplify

# %%
#Establishing Population Groups 

# Define phenotype groups
phenotype_groups <- list(
  Group1 = c("CD34+CD45RA-CLEC12A-", "CD34-CD45RA-CLEC12A-"), # Ra-C-
  Group2 = c("CD34+CD45RA+CLEC12A-", "CD34-CD45RA+CLEC12A-"),   #Ra+C-
  Group3 = c("CD34-CD45RA-CLEC12A+", "CD34+CD45RA-CLEC12A+", "CD34+CD45RA+CLEC12A+", "CD34-CD45RA+CLEC12A+"), #C+
  Group4 = "CD10+", #Pro -B
  Group5 = "CD14CD15+" #Pro-NM
)

# Assign group labels to phenotypes
group_labels <- sapply(pheno.merge2, function(phenotype) {
  group <- names(phenotype_groups)[sapply(phenotype_groups, function(g) phenotype %in% g)]
  if (length(group) > 0) group else "Other"
})

# Add group labels to colData of the SCE object
colData(merge2)$Group <- group_labels

# Extract UMAP coordinates and group labels for plotting
umap_df <- as.data.frame(reducedDim(merge2, "UMAP"))
umap_df$Group <- colData(merge2)$Group

# Create UMAP plot
library(ggplot2)

gg_umap <- ggplot(umap_df, aes(x = UMAP1, y = UMAP2, color = Group)) +
  geom_point(alpha = 0.8, size = 1) +
  labs(
    title = "UMAP of Day 7 - Day 13 Gene Expression by Group",
    x = "UMAP1",
    y = "UMAP2",
    color = "Group"
  ) +
  theme_minimal(base_size = 14) +
  theme(
    plot.title = element_text(hjust = 0.5, face = "bold"),
    legend.position = "bottom",
    legend.text = element_text(size = 12),       # Increase legend text size
    legend.key.size = unit(1.5, "cm")           # Increase legend color box size
  )

# Print the UMAP plot
print(gg_umap)
# Out:
# plot without title

# %%
gg_umap <- ggplot(umap_df, aes(x = UMAP1, y = UMAP2)) +
  geom_point(aes(color = ifelse(Group == "Group2", "Ra+C-", "Other")),
             alpha = ifelse(umap_df$Group == "Group2", 1, 0.2), size = 1) +
  scale_color_manual(
    values = c("Ra+C-" = "red", "Other" = "gray"),
    name = "Group"
  ) +
  labs(
    title = "Ra+C- Population Overlaid on Main UMAP",
    x = "UMAP1",
    y = "UMAP2"
  ) +
  theme_minimal(base_size = 14) +
  theme(
    plot.title = element_text(hjust = 0.5, face = "bold"),
    legend.position = "right",
    legend.text = element_text(size = 12),
    legend.title = element_text(size = 14, face = "bold")
  )

# Print the UMAP plot
print(gg_umap)
# Out:
# plot without title

# %%
rownames(assay(merge2, "logcounts"))
# Out:
#     [1] "MIR1302-2HG"       "FAM138A"           "OR4F5"
#     [4] "AL627309.1"        "AL627309.3"        "AL627309.2"
#     [7] "AL627309.5"        "AL627309.4"        "AP006222.2"
#    [10] "AL732372.1"        "OR4F29"            "AC114498.1"
#    [13] "OR4F16"            "AL669831.2"        "LINC01409"
#    [16] "FAM87B"            "LINC01128"         "LINC00115"
#    [19] "FAM41C"            "AL645608.6"        "AL645608.2"
#    [22] "AL645608.4"        "LINC02593"         "SAMD11"
#    [25] "NOC2L"             "KLHL17"            "PLEKHN1"
#    [28] "PERM1"             "AL645608.7"        "HES4"
#    [31] "ISG15"             "AL645608.1"        "AGRN"
#    [34] "AL645608.5"        "AL645608.8"        "RNF223"
#    [37] "C1orf159"          "AL390719.3"        "LINC01342"
#    [40] "AL390719.2"        "TTLL10-AS1"        "TTLL10"
#    [43] "TNFRSF18"          "TNFRSF4"           "SDF4"
#    [46] "B3GALT6"           "C1QTNF12"          "AL162741.1"
#    [49] "UBE2J2"            "LINC01786"         "SCNN1D"
#    [52] "ACAP3"             "PUSL1"             "INTS11"
#    [55] "AL139287.1"        "CPTP"              "TAS1R3"
#    [58] "DVL1"              "MXRA8"             "AURKAIP1"
#    [61] "CCNL2"             "MRPL20-AS1"        "MRPL20"
#    [64] "AL391244.2"        "ANKRD65"           "AL391244.1"
#    [67] "TMEM88B"           "LINC01770"         "VWA1"
#    [70] "ATAD3C"            "ATAD3B"            "ATAD3A"
#    [73] "TMEM240"           "SSU72"             "AL645728.1"
#    [76] "FNDC10"            "AL691432.4"        "AL691432.2"
#    [79] "MIB2"              "MMP23B"            "CDK11B"
#    [82] "FO704657.1"        "SLC35E2B"          "CDK11A"
#    [85] "SLC35E2A"          "NADK"              "GNB1"
#    [88] "AL109917.1"        "CALML6"            "TMEM52"
#    [91] "CFAP74"            "AL391845.2"        "GABRD"
#    [94] "AL391845.1"        "PRKCZ"             "AL590822.2"
#    [97] "PRKCZ-AS1"         "FAAP20"            "AL590822.1"
#   [100] "SKI"               "AL590822.3"        "MORN1"
#   [103] "AL589739.1"        "AL513477.2"        "RER1"
#   [106] "PEX10"             "PLCH2"             "AL139246.1"
#   [109] "AL139246.4"        "PANK4"             "HES5"
#   [112] "AL139246.5"        "TNFRSF14-AS1"      "TNFRSF14"
#   [115] "AL139246.3"        "PRXL2B"            "MMEL1"
#   [118] "AL831784.1"        "TTC34"             "AC242022.2"
#   [121] "AC242022.1"        "AL592464.2"        "AL592464.3"
#   [124] "AL592464.1"        "AL589702.1"        "ACTRT2"
#   [127] "PRDM16-DT"         "PRDM16"            "AL008733.1"
#   [130] "AL590438.1"        "AL354743.2"        "AL354743.1"
#   [133] "ARHGEF16"          "AL512413.1"        "MEGF6"
#   [136] "AL513320.1"        "TPRG1L"            "WRAP73"
#   [139] "TP73"              "AL136528.1"        "AL136528.2"
#   [142] "CCDC27"            "SMIM1"             "LRRC47"
#   [145] "AL365330.1"        "CEP104"            "DFFB"
#   [148] "C1orf174"          "LINC01134"         "LINC01346"
#   [151] "LINC01345"         "LINC02780"         "AL805961.1"
#   [154] "LINC01777"         "AL355602.1"        "Z98747.1"
#   [157] "LINC01646"         "AJAP1"             "Z98886.1"
#   [160] "BX005132.1"        "LINC02781"         "LINC02782"
#   [163] "AL139823.1"        "Z98259.3"          "Z98259.2"
#   [166] "Z98259.1"          "AL365255.1"        "NPHP4"
#   [169] "KCNAB2"            "CHD5"              "RPL22"
#   [172] "AL031847.1"        "RNF207"            "ICMT"
#   [175] "LINC00337"         "HES3"              "GPR153"
#   [178] "ACOT7"             "AL031848.2"        "HES2"
#   [181] "ESPN"              "AL031848.1"        "TNFRSF25"
#   [184] "PLEKHG5"           "NOL9"              "TAS1R1"
#   [187] "ZBTB48"            "KLHL21"            "PHF13"
#   [190] "THAP3"             "DNAJC11"           "LINC01672"
#   [193] "AL591163.1"        "CAMTA1-DT"         "CAMTA1"
#   [196] "AL512330.1"        "CAMTA1-IT1"        "Z97987.1"
#   [199] "AL365194.1"        "AL359881.3"        "AL359881.2"
#   [202] "AL359881.1"        "VAMP3"             "Z98884.2"
#   [205] "PER3"              "Z98884.1"          "UTS2"
#   [208] "TNFRSF9"           "PARK7"             "AL034417.4"
#   [211] "AL034417.3"        "ERRFI1"            "AL034417.2"
#   [214] "LINC01714"         "AL358876.2"        "SLC45A1"
#   [217] "RERE"              "RERE-AS1"          "AL357552.2"
#   [220] "ENO1"              "ENO1-AS1"          "CA6"
#   [223] "SLC2A7"            "SLC2A5"            "GPR157"
#   [226] "MIR34AHG"          "LNCTAM34A"         "H6PD"
#   [229] "SPSB1"             "BX323043.1"        "LINC02606"
#   [232] "AL928921.1"        "SLC25A33"          "TMEM201"
#   [235] "PIK3CD"            "PIK3CD-AS1"        "PIK3CD-AS2"
#   [238] "CLSTN1"            "CTNNBIP1"          "AL357140.1"
#   [241] "AL357140.4"        "LZIC"              "AL357140.2"
#   [244] "NMNAT1"            "AL603962.1"        "RBP7"
#   [247] "UBE4B"             "KIF1B"             "AL139424.3"
#   [250] "AL139424.2"        "PGD"               "AL139424.1"
#   [253] "CENPS"             "CORT"              "DFFA"
#   [256] "AL354956.1"        "PEX14"             "AL139423.2"
#   [259] "CASZ1"             "AL139423.1"        "C1orf127"
#   [262] "TARDBP"            "MASP2"             "AL109811.2"
#   [265] "SRM"               "EXOSC10"           "AL109811.1"
#   [268] "EXOSC10-AS1"       "MTOR"              "MTOR-AS1"
#   [271] "ANGPTL7"           "UBIAD1"            "AL031291.1"
#   [274] "DISP3"             "AL590989.1"        "LINC01647"
#   [277] "AL031731.1"        "FBXO2"             "FBXO44"
#   [280] "FBXO6"             "MAD2L2"            "DRAXIN"
#   [283] "AGTRAP"            "C1orf167"          "AL953897.1"
#   [286] "MTHFR"             "CLCN6"             "NPPA"
#   [289] "NPPB"              "AL021155.5"        "KIAA2013"
#   [292] "PLOD1"             "AL096840.2"        "MFN2"
#   [295] "MIIP"              "TNFRSF8"           "AL357835.1"
#   [298] "TNFRSF1B"          "VPS13D"            "LINC02766"
#   [301] "DHRS3"             "AC254633.1"        "AADACL4"
#   [304] "AADACL3"           "C1orf158"          "PRAMEF12"
#   [307] "PRAMEF1"           "LINC01784"         "PRAMEF11"
#   [310] "HNRNPCL1"          "PRAMEF2"           "PRAMEF4"
#   [313] "PRAMEF10"          "PRAMEF7"           "PRAMEF6"
#   [316] "PRAMEF27"          "HNRNPCL3"          "PRAMEF25"
#   [319] "HNRNPCL2"          "AC245056.1"        "PRAMEF26"
#   [322] "HNRNPCL4"          "PRAMEF9"           "PRAMEF13"
#   [325] "PRAMEF18"          "PRAMEF5"           "PRAMEF8"
#   [328] "PRAMEF33"          "PRAMEF15"          "AC243961.1"
#   [331] "PRAMEF14"          "PRAMEF19"          "PRAMEF17"
#   [334] "PRAMEF20"          "LRRC38"            "AL354712.1"
#   [337] "PDPN"              "AL359771.1"        "PRDM2"
#   [340] "KAZN"              "AL357873.1"        "KAZN-AS1"
#   [343] "AL031293.1"        "TMEM51-AS1"        "TMEM51"
#   [346] "C1orf195"          "FHAD1"             "AL031283.2"
#   [349] "AL031283.3"        "AL031283.1"        "EFHD2"
#   [352] "CTRC"              "CELA2A"            "CELA2B"
#   [355] "CASP9"             "DNAJC16"           "AL121992.3"
#   [358] "AGMAT"             "AL121992.1"        "DDI2"
#   [361] "RSC1A1"            "AL121992.2"        "PLEKHM2"
#   [364] "AL450998.3"        "SLC25A34"          "SLC25A34-AS1"
#   [367] "TMEM82"            "FBLIM1"            "UQCRHL"
#   [370] "AL450998.2"        "SPEN"              "ZBTB17"
#   [373] "SRARP"             "AL355994.3"        "HSPB7"
#   [376] "CLCNKA"            "CLCNKB"            "FAM131C"
#   [379] "EPHA2"             "AL451042.2"        "AL451042.1"
#   [382] "ARHGEF19-AS1"      "ARHGEF19"          "AL109627.1"
#   [385] "CPLANE2"           "FBXO42"            "SZRD1"
#   [388] "SPATA21"           "NECAP2"            "LINC01772"
#   [391] "AL137802.2"        "AL137802.1"        "LINC01783"
#   [394] "NBPF1"             "AL137798.1"        "AL137798.2"
#   [397] "AL021920.1"        "AL021920.3"        "CROCC"
#   [400] "BX284668.1"        "BX284668.2"        "BX284668.5"
#   [403] "BX284668.6"        "MFAP2"             "AL049569.2"
#   [406] "AL049569.1"        "ATP13A2"           "SDHB"
#   [409] "PADI2"             "LINC02783"         "AL590644.1"
#   [412] "PADI1"             "PADI3"             "PADI4"
#   [415] "PADI6"             "RCC2-AS1"          "RCC2"
#   [418] "ARHGEF10L"         "LINC02810"         "ACTL8"
#   [421] "AL357509.1"        "LINC01654"         "IGSF21"
#   [424] "IGSF21-AS1"        "AL591896.1"        "KLHDC7A"
#   [427] "PAX7"              "TAS1R2"            "ALDH4A1"
#   [430] "IFFO2"             "AL137127.1"        "UBR4"
#   [433] "EMC1-AS1"          "EMC1"              "MRTO4"
#   [436] "AKR7A3"            "AKR7A2"            "SLC66A1"
#   [439] "CAPZB"             "MICOS10"           "AL031727.2"
#   [442] "NBL1"              "HTR6"              "TMCO4"
#   [445] "RNF186"            "AL391883.1"        "OTUD3"
#   [448] "PLA2G2E"           "PLA2G2A"           "PLA2G5"
#   [451] "PLA2G2D"           "PLA2G2F"           "Z98257.1"
#   [454] "PLA2G2C"           "UBXN10-AS1"        "UBXN10"
#   [457] "LINC01757"         "Z98257.2"          "VWA5B1"
#   [460] "AL020998.1"        "LINC01141"         "AL139254.1"
#   [463] "AL139254.2"        "AL139254.3"        "CAMK2N1"
#   [466] "MUL1"              "FAM43B"            "CDA"
#   [469] "PINK1"             "PINK1-AS"          "DDOST"
#   [472] "KIF17"             "SH2D5"             "AL663074.1"
#   [475] "HP1BP3"            "EIF4G3"            "AL031005.2"
#   [478] "ECE1"              "AL031005.1"        "AL031728.1"
#   [481] "AL592309.2"        "NBPF3"             "ALPL"
#   [484] "LINC02596"         "RAP1GAP"           "USP48"
#   [487] "LDLRAD2"           "HSPG2"             "CELA3B"
#   [490] "CELA3A"            "LINC01635"         "LINC00339"
#   [493] "CDC42"             "CDC42-AS1"         "CDC42-IT1"
#   [496] "WNT4"              "AL445253.1"        "ZBTB40"
#   [499] "ZBTB40-IT1"        "EPHA8"             "C1QA"
#   [502] "C1QC"              "C1QB"              "EPHB2"
#   [505] "AL512444.1"        "LACTBL1"           "TEX46"
#   [508] "KDM1A"             "AL031428.1"        "LUZP1"
#   [511] "HTR1D"             "LINC01355"         "AL109936.6"
#   [514] "HNRNPR"            "ZNF436"            "ZNF436-AS1"
#   [517] "AL109936.2"        "TCEA3"             "ASAP3"
#   [520] "E2F2"              "AL021154.1"        "ID3"
#   [523] "AL450043.1"        "MDS2"              "RPL11"
#   [526] "ELOA-AS1"          "ELOA"              "PITHD1"
#   [529] "LYPLA2"            "GALE"              "HMGCL"
#   [532] "FUCA1"             "CNR2"              "AL590609.3"
#   [535] "PNRC2"             "SRSF10"            "AL591178.1"
#   [538] "MYOM3"             "AL591178.2"        "IL22RA1"
#   [541] "IFNLR1"            "LINC02800"         "AL138902.1"
#   [544] "GRHL3"             "STPG1"             "NIPAL3"
#   [547] "RCAN3AS"           "RCAN3"             "NCMAP-DT"
#   [550] "NCMAP"             "SRRM1"             "AL445648.1"
#   [553] "CLIC4"             "RUNX3"             "AL445471.1"
#   [556] "AL445471.2"        "LINC02793"         "AL050344.1"
#   [559] "AL031432.1"        "SYF2"              "AL031432.4"
#   [562] "AL031432.5"        "RSRP1"             "AL031432.3"
#   [565] "RHD"               "TMEM50A"           "RHCE"
#   [568] "MACO1"             "LDLRAP1"           "AL606491.1"
#   [571] "MAN1C1"            "AL031280.1"        "SELENON"
#   [574] "AL020996.1"        "MTFR1L"            "AL020996.3"
#   [577] "AUNIP"             "AL033528.2"        "PAQR7"
#   [580] "STMN1"             "PAFAH2"            "EXTL1"
#   [583] "SLC30A2"           "AL391650.2"        "TRIM63"
#   [586] "PDIK1L"            "FAM110D"           "C1orf232"
#   [589] "AL391650.1"        "ZNF593"            "CNKSR1"
#   [592] "CATSPER4"          "CEP85"             "SH3BGRL3"
#   [595] "UBXN11"            "CD52"              "CRYBG2"
#   [598] "ZNF683"            "LIN28A"            "DHDDS"
#   [601] "AL513365.2"        "HMGN2"             "RPS6KA1"
#   [604] "AL512408.1"        "ARID1A"            "PIGV"
#   [607] "ZDHHC18"           "SFN"               "GPN2"
#   [610] "AL034380.1"        "GPATCH3"           "NUDC"
#   [613] "NR0B2"             "KDF1"              "TRNP1"
#   [616] "TENT5B"            "SLC9A1"            "AL590640.1"
#   [619] "WDTC1"             "TMEM222"           "SYTL1"
#   [622] "MAP3K6"            "FCN3"              "CD164L2"
#   [625] "GPR3"              "WASF2"             "FO393419.2"
#   [628] "BX293535.1"        "AHDC1"             "FGR"
#   [631] "LINC02574"         "IFI6"              "AL445490.1"
#   [634] "AL020997.5"        "FAM76A"            "STX12"
#   [637] "AL020997.2"        "AL020997.3"        "AL020997.4"
#   [640] "PPP1R8"            "THEMIS2"           "RPA2"
#   [643] "SMPDL3B"           "AL512288.1"        "XKR8"
#   [646] "EYA3"              "PTAFR"             "DNAJC8"
#   [649] "ATP5IF1"           "AL353622.1"        "AL353622.2"
#   [652] "SESN2"             "MED18"             "PHACTR4"
#   [655] "RCC1"              "SNHG3"             "TRNAU1AP"
#   [658] "SNHG12"            "TAF12"             "RAB42"
#   [661] "LINC01715"         "AL360012.1"        "GMEB1"
#   [664] "YTHDF2"            "OPRD1"             "AL009181.1"
#   [667] "EPB41"             "TMEM200B"          "AL357500.1"
#   [670] "SRSF4"             "MECR"              "AL590729.1"
#   [673] "PTPRU"             "LINC01756"         "AC092265.1"
#   [676] "AL645944.2"        "LINC01648"         "AL137076.1"
#   [679] "AL161638.2"        "AL161638.1"        "MATN1"
#   [682] "MATN1-AS1"         "AL137857.1"        "LAPTM5"
#   [685] "AL137027.1"        "LINC01778"         "AL445235.1"
#   [688] "SDC3"              "PUM1"              "NKAIN1"
#   [691] "SNRNP40"           "ZCCHC17"           "AL451070.1"
#   [694] "FABP3"             "SERINC2"           "LINC01226"
#   [697] "AC114488.1"        "TINAGL1"           "HCRTR1"
#   [700] "PEF1"              "AC114488.2"        "AC114488.3"
#   [703] "COL16A1"           "ADGRB2"            "AL354919.2"
#   [706] "SPOCD1"            "AL354919.1"        "AL136115.2"
#   [709] "PTP4A2"            "AL136115.1"        "AL136115.3"
#   [712] "KHDRBS1"           "AL445248.1"        "TMEM39B"
#   [715] "KPNA6"             "AL049795.2"        "TXLNA"
#   [718] "CCDC28B"           "AL049795.1"        "IQCC"
#   [721] "DCDC2B"            "TMEM234"           "EIF3I"
#   [724] "FAM167B"           "LCK"               "HDAC1"
#   [727] "MARCKSL1"          "AL109945.1"        "TSSK3"
#   [730] "FAM229A"           "BSDC1"             "ZBTB8B"
#   [733] "ZBTB8A"            "ZBTB8OS"           "RBBP4"
#   [736] "SYNC"              "AC114489.1"        "KIAA1522"
#   [739] "YARS"              "S100PBP"           "FNDC5"
#   [742] "HPCA"              "TMEM54"            "AL031602.2"
#   [745] "RNF19B"            "AL020995.1"        "AK2"
#   [748] "AZIN2"             "TRIM62"            "AL662907.3"
#   [751] "ZNF362"            "AL513327.3"        "A3GALT2"
#   [754] "AL513327.1"        "PHC2"              "AL513327.2"
#   [757] "ZSCAN20"           "CSMD2"             "HMGB4"
#   [760] "CSMD2-AS1"         "C1orf94"           "AC099565.1"
#   [763] "SMIM12"            "GJB5"              "GJB4"
#   [766] "AL121988.1"        "GJB3"              "GJA4"
#   [769] "AL122010.1"        "DLGAP3"            "TMEM35B"
#   [772] "ZMYM6"             "ZMYM1"             "AL590434.1"
#   [775] "SFPQ"              "ZMYM4"             "ZMYM4-AS1"
#   [778] "KIAA0319L"         "NCDN"              "AC004865.2"
#   [781] "TFAP2E"            "PSMB2"             "C1orf216"
#   [784] "CLSPN"             "AL354864.1"        "AGO4"
#   [787] "AGO1"              "AL139286.3"        "AL139286.2"
#   [790] "AGO3"              "AL138787.2"        "TEKT2"
#   [793] "ADPRHL2"           "COL8A2"            "TRAPPC3"
#   [796] "MAP7D1"            "THRAP3"            "SH3D21"
#   [799] "EVA1B"             "AL591845.1"        "STK40"
#   [802] "LSM10"             "OSCP1"             "MRPS15"
#   [805] "CSF3R"             "AL596257.1"        "AC117945.2"
#   [808] "AC117945.1"        "GRIK3"             "AL031430.1"
#   [811] "AL353604.1"        "LINC01137"         "ZC3H12A"
#   [814] "MEAF6"             "SNIP1"             "DNALI1"
#   [817] "GNL2"              "AL513220.1"        "RSPO1"
#   [820] "C1orf109"          "CDCA8"             "EPHA10"
#   [823] "MANEAL"            "AL929472.3"        "YRDC"
#   [826] "C1orf122"          "MTF1"              "AL929472.2"
#   [829] "INPP5B"            "SF3A3"             "FHL3"
#   [832] "UTP11"             "POU3F1"            "MIR3659HG"
#   [835] "LINC02786"         "AL390839.1"        "AL390839.2"
#   [838] "LINC01343"         "LINC01685"         "AL354702.2"
#   [841] "RRAGC"             "AL139260.1"        "MYCBP"
#   [844] "GJA9"              "RHBDL2"            "AKIRIN1"
#   [847] "NDUFS5"            "MACF1"             "AL356055.1"
#   [850] "AL442071.2"        "AL442071.1"        "BMP8A"
#   [853] "PABPC4"            "PABPC4-AS1"        "HEYL"
#   [856] "AL035404.2"        "NT5C1A"            "HPCAL4"
#   [859] "PPIE"              "BMP8B"             "OXCT2"
#   [862] "BMP8B-AS1"         "AL033527.3"        "AL033527.4"
#   [865] "LINC02811"         "TRIT1"             "MYCL"
#   [868] "AL033527.2"        "MFSD2A"            "CAP1"
#   [871] "PPT1"              "RLF"               "TMCO2"
#   [874] "AL050341.2"        "ZMPSTE24"          "COL9A2"
#   [877] "SMAP2"             "AL031985.4"        "ZFP69B"
#   [880] "AL031985.3"        "ZFP69"             "AL603839.3"
#   [883] "EXO5"              "AL603839.1"        "AL603839.2"
#   [886] "ZNF684"            "AL356379.2"        "RIMS3"
#   [889] "AL031289.2"        "AL031289.1"        "NFYC-AS1"
#   [892] "NFYC"              "KCNQ4"             "CITED4"
#   [895] "AC119677.1"        "AL391730.2"        "CTPS1"
#   [898] "SLFNL1-AS1"        "SLFNL1"            "SCMH1"
#   [901] "AC093151.8"        "AC093151.3"        "FOXO6"
#   [904] "AC093151.2"        "EDN2"              "HIVEP3"
#   [907] "AL445933.2"        "AC119676.1"        "AL158216.1"
#   [910] "GUCA2B"            "GUCA2A"            "FOXJ3"
#   [913] "AC096540.1"        "RIMKLA"            "ZMYND12"
#   [916] "PPCS"              "CCDC30"            "PPIH"
#   [919] "AC098484.4"        "AC098484.2"        "YBX1"
#   [922] "CLDN19"            "P3H1"              "C1orf50"
#   [925] "AC098484.1"        "TMEM269"           "SVBP"
#   [928] "ERMAP"             "AL512353.1"        "ZNF691"
#   [931] "SLC2A1"            "SLC2A1-AS1"        "AC099795.1"
#   [934] "FAM183A"           "EBNA1BP2"          "CFAP57"
#   [937] "TMEM125"           "C1orf210"          "TIE1"
#   [940] "MPL"               "AL139289.3"        "AL139289.2"
#   [943] "CDC20"             "ELOVL1"            "MED8"
#   [946] "AL139289.1"        "SZT2"              "SZT2-AS1"
#   [949] "HYI"               "HYI-AS1"           "PTPRF"
#   [952] "KDM4A"             "KDM4A-AS1"         "ST3GAL3"
#   [955] "AL451062.1"        "ARTN"              "AL357079.1"
#   [958] "IPO13"             "AL357079.2"        "DPH2"
#   [961] "ATP6V0B"           "B4GALT2"           "CCDC24"
#   [964] "SLC6A9"            "AL139220.2"        "KLF17"
#   [967] "KLF18"             "DMAP1"             "ERI3"
#   [970] "ERI3-IT1"          "RNF220"            "TMEM53"
#   [973] "ARMH1"             "KIF2C"             "AL592166.1"
#   [976] "RPS8"              "BEST4"             "PLK3"
#   [979] "TCTEX1D4"          "BTBD19"            "PTCH2"
#   [982] "EIF2B3"            "HECTD3"            "UROD"
#   [985] "ZSWIM5"            "LINC01144"         "HPDL"
#   [988] "MUTYH"             "TOE1"              "TESK2"
#   [991] "CCDC163"           "MMACHC"            "PRDX1"
#   [994] "AKR1A1"            "NASP"              "CCDC17"
#   [997] "GPBP1L1"           "TMEM69"            "IPP"
#  [1000] "AL604028.1"        "MAST2"             "PIK3R3"
#  [1003] "AL358075.1"        "AL358075.2"        "TSPAN1"
#  [1006] "P3R3URF"           "POMGNT1"           "LURAP1"
#  [1009] "RAD54L"            "LRRC41"            "UQCRH"
#  [1012] "NSUN4"             "FAAH"              "LINC01398"
#  [1015] "DMBX1"             "TMEM275"           "MKNK1-AS1"
#  [1018] "KNCN"              "MKNK1"             "MOB3C"
#  [1168] "PRKAA2"            "FYB2"              "AL360295.1"
#  [1171] "C8A"               "C8B"               "AL161740.1"
#  [1174] "DAB1"              "AL390243.1"        "DAB1-AS1"
#  [1177] "AL445193.2"        "OMA1"              "AL035411.3"
#  [1180] "TACSTD2"           "MYSM1"             "AL136985.3"
#  [1183] "JUN"               "LINC01135"         "AL136985.2"
#  [1186] "AL136985.1"        "LINC02777"         "LINC01358"
#  [1189] "AL592431.2"        "AL592431.1"        "AC093425.1"
#  [1192] "AC093424.1"        "FGGY"              "AL035416.1"
#  [1195] "HOOK1"             "CYP2J2"            "C1orf87"
#  [1198] "LINC02778"         "LINC01748"         "AC099792.1"
#  [1201] "NFIA"              "NFIA-AS2"          "NFIA-AS1"
#  [1204] "AC099791.3"        "AC099791.4"        "TM2D1"
#  [1207] "AC099791.2"        "PATJ"              "L1TD1"
#  [1210] "KANK4"             "USP1"              "DOCK7"
#  [1213] "ANGPTL3"           "AC103923.1"        "ATG4C"
#  [1216] "AC099794.1"        "LINC01739"         "AL162400.3"
#  [1219] "AL162400.1"        "AL162400.2"        "AC096543.1"
#  [1222] "LINC00466"         "AC096543.2"        "FOXD3-AS1"
#  [1225] "FOXD3"             "ALG6"              "ITGB3BP"
#  [1228] "BX004807.1"        "EFCAB7"            "DLEU2L"
#  [1231] "PGM1"              "ROR1"              "ROR1-AS1"
#  [1234] "AL445205.1"        "UBE2U"             "CACHD1"
#  [1237] "RAVER2"            "JAK1"              "LINC01359"
#  [1240] "AL357078.2"        "AK4"               "DNAJC6"
#  [1243] "AL139294.1"        "LEPROT"            "LEPR"
#  [1246] "AC119800.1"        "AL513493.1"        "PDE4B"
#  [1249] "AL590783.1"        "SGIP1"             "AL139147.1"
#  [1252] "TCTEX1D1"          "INSL5"             "WDR78"
#  [1255] "AL592161.1"        "MIER1"             "SLC35D1"
#  [1258] "C1orf141"          "AL133320.2"        "IL23R"
#  [1261] "IL12RB2"           "SERBP1"            "LINC01702"
#  [1264] "GADD45A"           "GNG12"             "GNG12-AS1"
#  [1267] "DIRAS3"            "WLS"               "RPE65"
#  [1270] "DEPDC1"            "AL138789.1"        "DEPDC1-AS1"
#  [1273] "AL035412.1"        "AL033530.1"        "AL691520.1"
#  [1276] "LINC01707"         "LINC02791"         "LINC01758"
#  [1279] "AL359894.1"        "LRRC7"             "AL117353.1"
#  [1282] "AL158840.1"        "LRRC40"            "SRSF11"
#  [1285] "AL353771.1"        "ANKRD13C"          "HHLA3"
#  [1288] "AL158839.1"        "CTH"               "AL354872.2"
#  [1291] "LINC01788"         "AL513285.1"        "PTGER3"
#  [1294] "AL031429.1"        "AL031429.2"        "ZRANB2-AS1"
#  [1297] "ZRANB2"            "ZRANB2-AS2"        "NEGR1"
#  [1300] "AL354949.1"        "NEGR1-IT1"         "AL513166.1"
#  [1303] "AL583808.1"        "LINC02796"         "LINC02797"
#  [1306] "LINC01360"         "LINC02238"         "AL591463.1"
#  [1309] "LRRIQ3"            "FPGT"              "TNNI3K"
#  [1312] "AC093158.1"        "AC105271.1"        "LRRC53"
#  [1615] "SYPL2"             "ATXN7L2"           "CYB561D1"
#  [1618] "AMIGO1"            "GPR61"             "AL355310.3"
#  [1621] "GNAI3"             "AL355310.1"        "GNAT2"
#  [1624] "AMPD2"             "AL355310.2"        "GSTM4"
#  [1627] "GSTM2"             "GSTM1"             "AC000032.1"
#  [1630] "GSTM5"             "AL158847.1"        "GSTM3"
#  [1633] "EPS8L3"            "LINC01768"         "AL450468.1"
#  [1636] "AL450468.2"        "CSF1"              "AHCYL1"
#  [1639] "STRIP1"            "AL160006.1"        "ALX3"
#  [1642] "LINC01397"         "UBL4B"             "SLC6A17"
#  [1645] "AL355990.1"        "AL355990.2"        "LINC02586"
#  [1648] "KCNC4"             "RBM15-AS1"         "RBM15"
#  [1651] "LAMTOR5-AS1"       "SLC16A4"           "AL355488.1"
#  [1654] "LAMTOR5"           "PROK1"             "AL358215.1"
#  [1657] "AL358215.2"        "CYMP-AS1"          "KCNA10"
#  [1660] "KCNA2"             "AL365361.1"        "KCNA3"
#  [1663] "CD53"              "AL360270.2"        "AL360270.1"
#  [1666] "LRIF1"             "AL360270.3"        "DRAM2"
#  [1669] "CEPT1"             "AL355816.1"        "AL355816.2"
#  [1672] "DENND2D"           "CHI3L2"            "CHIA"
#  [1675] "AL356387.1"        "PIFO"              "OVGP1"
#  [1678] "AL390195.2"        "AL390195.1"        "WDR77"
#  [1681] "ATP5PB"            "C1orf162"          "TMIGD3"
#  [1684] "ADORA3"            "RAP1A"             "LINC01160"
#  [1687] "INKA2"             "INKA2-AS1"         "AL049557.1"
#  [1690] "DDX20"             "KCND3"             "KCND3-IT1"
#  [1693] "KCND3-AS1"         "LINC01750"         "AL445426.1"
#  [1696] "CTTNBP2NL"         "WNT2B"             "AL354760.1"
#  [1699] "ST7L"              "CAPZA1"            "MOV10"
#  [1702] "AL603832.1"        "RHOC"              "PPM1J"
#  [1705] "AL603832.2"        "TAFA3"             "LINC01356"
#  [1708] "LINC01357"         "SLC16A1"           "SLC16A1-AS1"
#  [1711] "AL390242.1"        "LRIG2-DT"          "LRIG2"
#  [1714] "MAGI3"             "PHTF1"             "RSBN1"
#  [1717] "AL137856.1"        "PTPN22"            "AP4B1-AS1"
#  [1720] "BCL2L15"           "AP4B1"             "DCLRE1B"
#  [1723] "HIPK1-AS1"         "HIPK1"             "OLFML3"
#  [1726] "AL591742.2"        "SYT6"              "AL121999.1"
#  [1729] "TRIM33"            "BCAS2"             "DENND2C"
#  [1732] "AMPD1"             "NRAS"              "CSDE1"
#  [1735] "SIKE1"             "SYCP1"             "TSHB"
#  [1738] "TSPAN2"            "LINC01765"         "AL049825.1"
#  [1741] "NGF-AS1"           "NGF"               "AL512638.3"
#  [1744] "VANGL1"            "CASQ2"             "NHLH2"
#  [1747] "LINC01649"         "SLC22A15"          "AL365318.1"
#  [1750] "MAB21L3"           "LINC01779"         "AL355538.1"
#  [1753] "ATP1A1"            "ATP1A1-AS1"        "LINC01762"
#  [1756] "AL136376.1"        "AL390066.1"        "AL390066.2"
#  [1759] "CD58"              "IGSF3"             "C1orf137"
#  [1762] "CD2"               "AL157904.1"        "PTGFRN"
#  [1909] "HIST2H2AA3"        "HIST2H2AA4"        "HIST2H3A"
#  [1912] "HIST2H4B"          "AC239868.1"        "HIST2H2BE"
#  [1915] "HIST2H2AC"         "HIST2H2AB"         "BOLA1"
#  [1918] "SV2A"              "SF3B4"             "MTMR11"
#  [1921] "OTUD7B"            "AC244033.2"        "VPS45"
#  [1924] "PLEKHO1"           "AC242988.2"        "ANP32E"
#  [1927] "AC242988.1"        "CA14"              "APH1A"
#  [1930] "C1orf54"           "CIART"             "MRPS21"
#  [1933] "PRPF3"             "RPRD2"             "TARS2"
#  [1936] "ECM1"              "FALEC"             "AL356356.1"
#  [1939] "ADAMTSL4"          "ADAMTSL4-AS1"      "MCL1"
#  [1942] "ENSA"              "GOLPH3L"           "HORMAD1"
#  [1945] "CTSS"              "CTSK"              "ARNT"
#  [1948] "CTXND2"            "SETDB1"            "CERS2"
#  [1951] "AL590133.2"        "AL590133.1"        "ANXA9"
#  [1954] "MINDY1"            "PRUNE1"            "BNIPL"
#  [1957] "C1orf56"           "CDC42SE1"          "MLLT11"
#  [1960] "GABPB2"            "AL592424.1"        "SEMA6C"
#  [1963] "TNFAIP8L2"         "SCNM1"             "LYSMD1"
#  [1966] "TMOD4"             "VPS72"             "PIP5K1A"
#  [1969] "PSMD4"             "ZNF687-AS1"        "ZNF687"
#  [1972] "PI4KB"             "AL391069.3"        "RFX5"
#  [1975] "AL391069.1"        "AL391069.2"        "SELENBP1"
#  [1978] "PSMB4"             "POGZ"              "CGN"
#  [1981] "TUFT1"             "AL365436.2"        "SNX27"
#  [1984] "AL391335.1"        "CELF3"             "AL589765.1"
#  [1987] "RIIAD1"            "AL589765.7"        "MRPL9"
#  [1990] "OAZ3"              "AL589765.4"        "AL589765.2"
#  [1993] "AL589765.5"        "TDRKH"             "TDRKH-AS1"
#  [1996] "AL589765.6"        "LINGO4"            "RORC"
#  [1999] "C2CD4D"            "C2CD4D-AS1"        "THEM5"
#  [2002] "THEM4"             "AL450992.2"        "AL450992.3"
#  [2005] "S100A10"           "AL450992.1"        "S100A11"
#  [2008] "TCHHL1"            "TCHH"              "AL589986.1"
#  [2011] "RPTN"              "FLG-AS1"           "AL589986.2"
#  [2014] "HRNR"              "FLG"               "FLG2"
#  [2017] "CRNN"              "LCE5A"             "CRCT1"
#  [2020] "LCE3E"             "LCE3D"             "LCE3C"
#  [2023] "LCE3B"             "LCE3A"             "LCE2D"
#  [2026] "LCE2C"             "LCE2B"             "LCE2A"
#  [2029] "LCE4A"             "C1orf68"           "KPRP"
#  [2032] "LCE1F"             "LCE1E"             "LCE1D"
#  [2035] "LCE1C"             "LCE1B"             "LCE1A"
#  [2038] "LCE6A"             "AL162596.1"        "SMCP"
#  [2041] "IVL"               "LINC01527"         "SPRR5"
#  [2044] "SPRR4"             "SPRR1A"            "SPRR3"
#  [2047] "SPRR1B"            "SPRR2D"            "SPRR2A"
#  [2050] "SPRR2B"            "SPRR2E"            "SPRR2F"
#  [2053] "SPRR2G"            "AL161636.1"        "LELP1"
#  [2056] "PRR9"              "LOR"               "PGLYRP3"
#  [2059] "PGLYRP4"           "S100A9"            "S100A12"
#  [2062] "S100A8"            "S100A7A"           "S100A7L2"
#  [2065] "S100A7"            "BX470102.1"        "S100A6"
#  [2068] "S100A5"            "S100A4"            "S100A3"
#  [2071] "S100A2"            "BX470102.2"        "S100A16"
#  [2074] "S100A14"           "S100A13"           "S100A1"
#  [2077] "AL162258.2"        "CHTOP"             "SNAPIN"
#  [2080] "ILF2"              "NPR1"              "INTS3"
#  [2083] "AL513523.4"        "AL513523.3"        "SLC27A3"
#  [2086] "GATAD2B"           "AL358472.5"        "DENND4B"
#  [2089] "CRTC2"             "SLC39A1"           "AL358472.4"
#  [2092] "AL358472.3"        "CREB3L4"           "JTB"
#  [2095] "AL358472.2"        "RAB13"             "RPS27"
#  [2098] "NUP210L"           "TPM3"              "C1orf189"
#  [2101] "C1orf43"           "UBAP2L"            "HAX1"
#  [2104] "AQP10"             "ATP8B2"            "IL6R-AS1"
#  [2107] "IL6R"              "SHE"               "AL162591.2"
#  [2110] "TDRD10"            "UBE2Q1"            "UBE2Q1-AS1"
#  [2113] "AL592078.2"        "CHRNB2"            "AL592078.1"
# ...
# [35899] "POU3F4"            "CYLC1"             "RPS6KA6"
# [35902] "HDX"               "APOOL"             "SATL1"
# [35905] "AC003001.1"        "ZNF711"            "POF1B"
# [35908] "CHM"               "DACH2"             "KLHL4"
# [35911] "Z83818.2"          "CPXCR1"            "AL121872.1"
# [35914] "TGIF2LX"           "AL121823.1"        "PABPC5-AS1"
# [35917] "PABPC5"            "PCDH11X"           "NAP1L3"
# [35920] "FAM133A"           "AL022151.1"        "DIAPH2"
# [35923] "RPA4"              "DIAPH2-AS1"        "AL157778.1"
# [35926] "PCDH19"            "TNMD"              "TSPAN6"
# [35929] "SRPX2"             "SYTL4"             "CSTF2"
# [35932] "NOX1"              "XKRX"              "ARL13A"
# [35935] "TRMT2B"            "TRMT2B-AS1"        "TMEM35A"
# [35938] "CENPI"             "DRP2"              "TAF7L"
# [35941] "TIMM8A"            "BTK"               "RPL36A"
# [35944] "GLA"               "HNRNPH2"           "ARMCX4"
# [35947] "ARMCX1"            "ARMCX6"            "ARMCX3"
# [35950] "ARMCX3-AS1"        "AC234775.3"        "AC234775.4"
# [35953] "ARMCX2"            "NXF5"              "ZMAT1"
# [35956] "TCEAL2"            "TCEAL6"            "Z70719.1"
# [35959] "BEX5"              "TCP11X1"           "NXF2"
# [35962] "NXF2B"             "TCP11X2"           "TMSB15A"
# [35965] "ARMCX5"            "ARMCX5-GPRASP2"    "AL035427.1"
# [35968] "GPRASP1"           "AL035427.2"        "GPRASP2"
# [35971] "ARMCX5-GPRASP2"    "BHLHB9"            "LINC00630"
# [35974] "Z68871.1"          "RAB40AL"           "Z95624.1"
# [35977] "Z93943.1"          "BEX1"              "NXF3"
# [35980] "BEX4"              "TCEAL8"            "TCEAL5"
# [35983] "BEX2"              "TCEAL7"            "TCEAL9"
# [35986] "BEX3"              "AL117327.1"        "Z69733.1"
# [35989] "RAB40A"            "AL021308.1"        "TCEAL4"
# [35992] "TCEAL3"            "TCEAL3-AS1"        "TCEAL1"
# [36148] "DCAF12L1"          "PRR32"             "AL591643.1"
# [36151] "AL008633.1"        "ACTRT1"            "SMARCA1"
# [36154] "OCRL"              "APLN"              "AL022162.1"
# [36157] "XPNPEP2"           "SASH3"             "AL023653.1"
# [36160] "ZDHHC9"            "AL034405.1"        "UTP14A"
# [36163] "BCORL1"            "ELF4"              "AIFM1"
# [36166] "AL139234.1"        "RAB33A"            "ZNF280C"
# [36169] "SLC25A14"          "GPR119"            "RBMX2"
# [36172] "Z82195.3"          "ENOX2"             "LINC01201"
# [36175] "ARHGAP36"          "IGSF1"             "AL135784.1"
# [36178] "OR13H1"            "AL365256.1"        "FIRRE"
# [36181] "STK26"             "FRMD7"             "RAP2C"
# [36184] "RAP2C-AS1"         "MBNL3"             "HS6ST2"
# [36187] "HS6ST2-AS1"        "USP26"             "TFDP3"
# [36190] "GPC4"              "GPC3"              "AC002407.1"
# [36193] "CCDC160"           "PHF6"              "HPRT1"
# [36196] "MIR503HG"          "LINC00629"         "PLAC1"
# [36199] "AL672032.1"        "FAM122B"           "FAM122C"
# [36202] "MOSPD1"            "LINC02243"         "SMIM10"
# [36205] "RTL8B"             "RTL8C"             "AL136169.1"
# [36208] "RTL8A"             "SMIM10L2B-AS1"     "SMIM10L2B"
# [36211] "ETDB"              "AC234771.1"        "CT55"
# [36214] "ZNF75D"            "ETDA"              "ETDC"
# [36217] "AL590282.2"        "ZNF449"            "SMIM10L2A"
# [36220] "INTS6L-AS1"        "INTS6L"            "CT45A1"
# [36223] "CT45A3"            "CT45A5"            "CT45A6"
# [36226] "CT45A2"            "CT45A7"            "CT45A8"
# [36229] "CT45A9"            "CT45A10"           "SAGE1"
# [36232] "MMGT1"             "SLC9A6"            "FHL1"
# [36235] "MAP7D3"            "ADGRG4"            "BRS3"
# [36238] "HTATSF1"           "VGLL1"             "LINC00892"
# [36241] "CD40LG"            "ARHGEF6"           "AL683813.1"
# [36244] "RBMX"              "GPR101"            "AL035443.1"
# [36247] "ZIC3"              "Z96074.1"          "FGF13"
# [36250] "AL031386.1"        "FGF13-AS1"         "F9"
# [36253] "MCF2"              "ATP11C"            "CXorf66"
# [36256] "AL589987.2"        "FO393408.1"        "SOX3"
# [36259] "AL844175.1"        "LINC00632"         "CDR1"
# [36262] "AL451048.1"        "SPANXB1"           "LDOC1"
# [36265] "SPANXA2-OT1"       "SPANXC"            "SPANXA1"
# [36268] "SPANXA2"           "AC235097.1"        "SPANXD"
# [36271] "MAGEC3"            "MAGEC1"            "AL031073.2"
# [36274] "MAGEC2"            "SPANXN4"           "AC239727.1"
# [36277] "SPANXN3"           "SLITRK4"           "SPANXN2"
# [36280] "AL500522.1"        "AL713923.1"        "SPANXN1"
# [36283] "AL109653.3"        "SLITRK2"           "CXorf51B"
# [36286] "CXorf51A"          "AL589669.1"        "AL591022.1"
# [36289] "AC016925.3"        "L29074.1"          "FMR1-AS1"
# [36292] "FMR1"              "FMR1-IT1"          "FMR1NB"
# [36295] "AC002368.1"        "AFF2"              "AFF2-IT1"
# [36298] "AC231656.1"        "IDS"               "AC244197.2"
# [36460] "PCDH11Y"           "TSPY2"             "LINC00280"
# [36463] "TTTY1B"            "TTTY2B"            "TTTY21B"
# [36466] "TTTY7"             "TTTY8B"            "AMELY"
# [36469] "TBL1Y"             "AC011297.1"        "PRKY"
# [36472] "TTTY12"            "AC064829.1"        "TTTY18"
# [36475] "TTTY19"            "TTTY20"            "TSPY4"
# [36478] "TSPY8"             "FAM197Y7"          "FAM197Y6"
# [36481] "TSPY3"             "TSPY1"             "TSPY9P"
# [36484] "TSPY10"            "TTTY8"             "TTTY7B"
# [36487] "TTTY21"            "TTTY2"             "TTTY1"
# [36490] "TTTY22"            "AC010891.1"        "TTTY23"
# [36493] "USP9Y"             "AC244213.1"        "DDX3Y"
# [36496] "UTY"               "TMSB4Y"            "VCY"
# [36499] "VCY1B"             "AC010723.1"        "NLGN4Y"
# [36502] "NLGN4Y-AS1"        "AC011751.1"        "FAM41AY1"
# [36505] "FAM224B"           "CDY2B"             "CDY2A"
# [36508] "FAM224A"           "FAM41AY2"          "AC022486.1"
# [36511] "HSFY1"             "TTTY9B"            "HSFY2"
# [36514] "TTTY14"            "AC007244.1"        "AC010889.1"
# [36517] "KDM5D"             "AC010889.2"        "TTTY10"
# [36520] "EIF1AY"            "AC009494.2"        "RPS4Y2"
# [36523] "AC007876.1"        "PRORY"             "AC010086.3"
# [36526] "RBMY1B"            "RBMY1A1"           "TTTY13"
# [36529] "AC024236.1"        "RBMY1D"            "RBMY1E"
# [36532] "PRY2"              "AC007359.1"        "TTTY6B"
# [36535] "RBMY1F"            "TTTY5"             "RBMY1J"
# [36538] "AC008175.1"        "TTTY6"             "PRY"
# [36541] "TTTY17A"           "TTTY4"             "BPY2"
# [36544] "DAZ1"              "DAZ2"              "PRYP3"
# [36547] "TTTY3B"            "CDY1B"             "TTTY17B"
# [36550] "TTTY4B"            "BPY2B"             "DAZ3"
# [36553] "DAZ4"              "BPY2C"             "TTTY4C"
# [36556] "TTTY17C"           "LINC00266-4P"      "CDY1"
# [36559] "TTTY3"             "MT-ND1"            "MT-ND2"
# [36562] "MT-CO1"            "MT-CO2"            "MT-ATP8"
# [36565] "MT-ATP6"           "MT-CO3"            "MT-ND3"
# [36568] "MT-ND4L"           "MT-ND4"            "MT-ND5"
# [36571] "MT-ND6"            "MT-CYB"            "BX004987.1"
# [36574] "AC145212.1"        "MAFIP"             "AC011043.1"
# [36577] "AC011043.2"        "AC011841.1"        "BX072566.1"
# [36580] "AL354822.1"        "AL592183.1"        "AC240274.1"
# [36583] "AC213203.2"        "AC213203.1"        "AC004556.3"
# [36586] "AC233755.2"        "AC233755.1"        "AC136352.3"
# [36589] "AC136352.2"        "AC171558.3"        "AC171558.1"
# [36592] "AC133551.1"        "AC136612.1"        "AC136616.1"
# [36595] "AC136616.3"        "AC136616.2"        "AC141272.1"
# [36598] "AC023491.2"        "AC007325.1"        "AC007325.4"
# [36601] "AC007325.2"

# %%
#Visualizing CD3 Expression across all populations and Timepoints

# Assuming "merge2" contains the logcounts assay and CD3 is the gene of interest
library(ggplot2)

# Extract CD3 gene expression values
cd3_expression <- assay(merge2, "logcounts")["CD7", ]

# Add CD3 expression to the UMAP dataframe
umap_df$CD3_expression <- cd3_expression

# Create the plot
gg_umap_cd3 <- ggplot(umap_df, aes(x = UMAP1, y = UMAP2)) +
  geom_point(
    aes(color = CD3_expression),
    alpha = ifelse(umap_df$CD3_expression > 0, 1, 0.2),
    size = 1
  ) +
  scale_color_gradient(
    low = "gray",
    high = "red",
    name = "LogFold CD3 Expression"
  ) +
  labs(
    title = "UMAP Highlighting CD7 Gene Expression",
    x = "UMAP1",
    y = "UMAP2"
  ) +
  theme_minimal(base_size = 14) +
  theme(
    plot.title = element_text(hjust = 0.5, face = "bold"),
    legend.position = "bottom",
    legend.title = element_text(face = "bold")
  )

print(gg_umap_cd3)
# Out:
# plot without title

# %%
#Establishing T cell Genes 

T_genes <- c("TCF3", "RAG1", "GATA3", "TCF7","NOTCH1","BCL11B", "CD7") 
B_genes <- c("TCF4","PAX5","TCF3","RAG1","RAG2", "BCL11A","EBF1","CD79A","MEF2C" )
gene_presence <- B_genes %in% rownames(merge2)
names(gene_presence) <- B_genes
gene_presence
# Out:
#   TCF4   PAX5   TCF3   RAG1   RAG2 BCL11A   EBF1  CD79A  MEF2C
#   TRUE   TRUE   TRUE   TRUE   TRUE   TRUE   TRUE   TRUE   TRUE

# %%
"EBF1" %in% rownames(merge2)
# Out:
# [1] TRUE

# %%
unique(pheno.merge2)
# Out:
#  [1] "CD34+CD45RA-CLEC12A-" "CD34-CD45RA-CLEC12A+" "CD34+CD45RA-CLEC12A+"
#  [4] "CD34+CD45RA+CLEC12A-" "CD34-CD45RA+CLEC12A-" "CD34+CD45RA+CLEC12A+"
#  [7] "CD34-CD45RA-CLEC12A-" "CD34-CD45RA+CLEC12A+" "CD14CD15+"
# [10] "CD10+"

# %%
# Check unique values in Phenotype_Group
# Check unique values in Phenotype_Group
unique(expression_df$Phenotype_Group)
# Out:
# [1] "Group1" "Group3" "Group2" "Other"  "Group4"

# %%
# T Cell Gene Expression Across Starting populations

library(ggplot2)

# Define the genes of interest
genes_of_interest <- T_genes  # Replace with actual gene names

# Define the phenotypes to include in the comparison
phenotypes_of_interest <- c("CD34+CD45RA-CLEC12A-", "CD34-CD45RA-CLEC12A-", "CD34+CD45RA+CLEC12A-", "CD34-CD45RA+CLEC12A-",
"CD34-CD45RA-CLEC12A+", "CD34+CD45RA-CLEC12A+", "CD34+CD45RA+CLEC12A+", "CD34-CD45RA+CLEC12A+", "CD10+", "CD14CD15+")  # Replace with actual phenotype names

# Extract expression data for the genes
gene_expression <- assay(merge2, "logcounts")[genes_of_interest, ]

# Combine data into a data frame
expression_df <- data.frame(
  Expression = as.vector(gene_expression),
  Gene = rep(genes_of_interest, each = ncol(gene_expression)),
  Phenotype = rep(pheno.merge2, times = length(genes_of_interest))
)

expression_df$Phenotype_Group <- sapply(expression_df$Phenotype, function(phenotype) {
  group <- names(phenotype_groups)[sapply(phenotype_groups, function(group) phenotype %in% group)]
  if (length(group) > 0) group else "Other"
})


# Example with extended plot width and group labels
library(ggplot2)

# Adjusting the plot size (for saving or interactive sessions)
options(repr.plot.width = 12)  # Set a larger width for plotting

# Create the plot
ggplot(expression_df, aes(x = Phenotype_Group, y = Expression, fill = Phenotype_Group)) +
  geom_violin(trim = TRUE, alpha = 0.7) +
  facet_wrap(~ Gene, scales = "free_y") +
  labs(
    title = "T Cell Gene Expression Within Key Populations",
    x = "Phenotype Group",
    y = "Expression"
  ) +
  coord_cartesian(ylim = c(0, 0.5)) +  # Adjust the y-axis range to control tail length
  theme_minimal(base_size = 14) +
  theme(
    axis.text.x = element_blank(),
    axis.ticks.x = element_blank(),
    legend.position = "bottom"
  )
# Out:
# plot without title

# %% [markdown]
# Great! Now lets do this again with B cell genes

# %%
#B Cell Gene Expression Across Populations 






library(ggplot2)

# Define the genes of interest
genes_of_interest <- B_genes  # Replace with actual gene names

# Define the phenotypes to include in the comparison
phenotypes_of_interest <- c("CD34+CD45RA-CLEC12A-", "CD34-CD45RA-CLEC12A-", "CD34+CD45RA+CLEC12A-", "CD34-CD45RA+CLEC12A-",
"CD34-CD45RA-CLEC12A+", "CD34+CD45RA-CLEC12A+", "CD34+CD45RA+CLEC12A+", "CD34-CD45RA+CLEC12A+", "CD10+", "CD14CD15+")  # Replace with actual phenotype names

# Extract expression data for the genes
gene_expression <- assay(merge2, "logcounts")[genes_of_interest, ]

# Combine data into a data frame
expression_df <- data.frame(
  Expression = as.vector(gene_expression),
  Gene = rep(genes_of_interest, each = ncol(gene_expression)),
  Phenotype = rep(pheno.merge2, times = length(genes_of_interest))
)

expression_df$Phenotype_Group <- sapply(expression_df$Phenotype, function(phenotype) {
  group <- names(phenotype_groups)[sapply(phenotype_groups, function(group) phenotype %in% group)]
  if (length(group) > 0) group else "Other"
})


# Example with extended plot width and group labels
library(ggplot2)

# Adjusting the plot size (for saving or interactive sessions)
options(repr.plot.width = 12)  # Set a larger width for plotting

# Create the plot
ggplot(expression_df, aes(x = Phenotype_Group, y = Expression, fill = Phenotype_Group)) +
  geom_violin(trim = TRUE, alpha = 0.7) +
  facet_wrap(~ Gene, scales = "free_y") +
  labs(
    title = "B Cell Gene Expression Within Key Populations",
    x = "Phenotype Group",
    y = "Log Fold Expression"
  ) +
  coord_cartesian(ylim = c(0, 1.5)) +  # Adjust the y-axis range to control tail length
  theme_minimal(base_size = 14) +
  theme(
    axis.text.x = element_blank(),
    axis.ticks.x = element_blank(),
    legend.position = "bottom"
  )
# Out:
# plot without title

# %%
# Check if CD7 exists in the rownames (genes) of the SCE object
"CD7" %in% rownames(merge2) # Replace merge2 with the name of your SCE object
# Out:
# [1] TRUE

# %%
# head(pheno.merge2)

# merge2

#index.cd10 <- which(pheno.merge2 == "CD10+")
#merge2.cd10 <- merge2[, index.cd10]

#merge2.cd10
# Out:
#             cell1Day_7             cell2Day_7             cell3Day_7
# "CD34+CD45RA-CLEC12A-" "CD34+CD45RA-CLEC12A-" "CD34+CD45RA-CLEC12A-"
#             cell4Day_7             cell5Day_7             cell6Day_7
# "CD34+CD45RA-CLEC12A-" "CD34+CD45RA-CLEC12A-" "CD34+CD45RA-CLEC12A-"
